# %%
DATASET_PATH = '/scratch/ceph/szalay/swei20/cancerHH/AceCanZ/data/bki'

# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sys.path.insert(0, '../..')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.dataset.cancerDataset import CancerDataset

# %%
ds=CancerDataset(DATASET_PATH, nImg = -1, isTest=False,smooth=None)

# %%
plt.matshow(ds.cov)

# %%
plt.matshow(ds.cov)

# %%
dimPCA = 8
ds.get_pc(dimPCA)
