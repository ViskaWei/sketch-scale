# %%
# DATASET = '/home/swei20/sketch-scale/data/kmat.xlsx'
DATASET = './data/kmat.xlsx'

# %%
from hillSimple import *

# %%
nCluster = 10

# %%
data,kmap,centers = run_hill_simple(DATASET, nCluster=nCluster, PCA_dim = 6)
# Out:
# Index(['k11', 'k12', 'k13', 'k14', 'k21', 'k22', 'k23', 'k24', 'k31', 'k32',
#        'k33', 'k34', 'k41', 'k42', 'k43', 'k44', 'k55', 'k56', 'k65', 'k66'],
#       dtype='object')
# (6400, 6)
# (6400, 2)
# center Id: [2248 5264 3951 5651 4568 3726 2733 5686 1075 5462]

# %%
plot_data(data,kmap)

# %%
outDir = './out/'

# %%
save_cluster_ids(data, nCluster, outDir=None,name='kMat')
# Out:
# Cluster1: [1691 1692 1693]..
# Cluster2: [17 18 63]..
# Cluster3: [1621 1622 1623]..
# Cluster4: [25 26 27]..
# Cluster5: [1109 1188 1189]..
# Cluster6: [1950 1951 1952]..
# Cluster7: [2462 2463 2464]..
# Cluster8: [1 2 3]..
# Cluster9: [33 34 35]..
# Cluster10: [19 20 21]..

# %%
save_centers(centers,nCluster,outDir=None,name='centers')
